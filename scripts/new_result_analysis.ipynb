# %% [markdown]
# # Hypothesis 1 And Concept-Copying Analysis
#
# This notebook combines the original `hypothesis1_analysis.ipynb` and `concept_copying_analysis.ipynb` workflows into a single analysis pass.
#
# It uses the shared improbable-bigram traced cache, the coherent 2-token concept cache, and the random two-token control set, then runs:
#
# - the Hypothesis 1 token-induction diagnostics
# - the concept-copying head diagnostics
#
# The shared repo-setup and cache-loading cell appears only once below.

# %%
import importlib
import sys
from pathlib import Path

import pandas as pd
from IPython.display import Markdown, display


def find_repo_root(start: Path) -> Path:
    candidates = []
    for candidate in (start, *start.parents):
        candidates.extend(
            [
                candidate,
                candidate / "dual-route-induction",
                candidate / "improbable-bigram-causality" / "dual-route-induction",
            ]
        )

    for candidate in candidates:
        if (candidate / "cache").exists() and (candidate / "scripts").exists():
            return candidate.resolve()

    raise FileNotFoundError(
        "Could not locate the dual-route-induction repo root from the current working directory."
    )


ROOT = find_repo_root(Path.cwd().resolve())
if str(ROOT / "scripts") not in sys.path:
    sys.path.insert(0, str(ROOT / "scripts"))

import new_analysis as h1

h1 = importlib.reload(h1)

h1.configure_matplotlib()
CACHE = h1.load_cache(ROOT)
DEFAULT_TOP_K = 32
ROOT
# Out:
# PosixPath('/Users/eugenejang/Workspace/improbable-bigram-causality/dual-route-induction')

# %% [markdown]
# ## Shared Cache Checks
#
# Run this once to verify that the traced cache and control cache are both available before either analysis section.

# %%
display(Markdown(h1.trace_consistency_markdown(CACHE)))
overview = h1.dataset_overview(CACHE)
display(overview)
# Out:
# ### Trace Consistency
# The prompt-summary JSON is not present in this repo snapshot. The notebook therefore uses the traced cache directly.
#                     dataset  examples  hallucinated_second_token  copied
# 0        Improbable summary       100                         32      68
# 1       Updated trace cache       100                         32      68
# 2     2-token concept cache        36                          0      36
# 3       Random phrase cache        35                          0      35
# 4  Multiscript bigram cache       100                          1      97
# 5         Wild bigram cache       100                          9      82

# %% [markdown]
# # Hypothesis 1 Analysis
#
# This notebook tests Hypothesis 1 for the improbable-bigram repetition setup:
#
# - token induction heads should keep attending to the desired earlier suffix token, measured with `NTM`
# - token induction heads should keep contributing to the correct second-token prediction, measured with `DLA`
#
# The notebook uses the traced cache in `updated_table1_literal`, the coherent 2-token concept cache in `selected_two_token_concepts`, and the random two-token control set in `random_tokens`.

# %%
summary = h1.build_pairwise_summary(CACHE, DEFAULT_TOP_K)
display(summary.round(6))
display(Markdown(h1.interpretation_markdown(CACHE, DEFAULT_TOP_K)))
# Out:
#                         metric                       comparison  left_mean  \
# 0              Token NTM (raw)            Hallucinated - Copied   0.235290
# 1              Token NTM (raw)  Hallucinated - 2-token concepts   0.235290
# 2              Token NTM (raw)            Hallucinated - Random   0.235290
# 3              Token NTM (raw)       Hallucinated - Multiscript   0.235290
# 4              Token NTM (raw)              Hallucinated - Wild   0.235290
# 5   Token NTM (value-weighted)            Hallucinated - Copied   0.415652
# 6   Token NTM (value-weighted)  Hallucinated - 2-token concepts   0.415652
# 7   Token NTM (value-weighted)            Hallucinated - Random   0.415652
# 8   Token NTM (value-weighted)       Hallucinated - Multiscript   0.415652
# 9   Token NTM (value-weighted)              Hallucinated - Wild   0.415652
# 10     Token correct-token DLA            Hallucinated - Copied   0.028317
# 11     Token correct-token DLA  Hallucinated - 2-token concepts   0.028317
# 12     Token correct-token DLA            Hallucinated - Random   0.028317
# 13     Token correct-token DLA       Hallucinated - Multiscript   0.028317
# 14     Token correct-token DLA              Hallucinated - Wild   0.028317
# 15      Hallucinated token DLA      Wrong-token - Correct-token   0.000159
#
#     right_mean      diff    ci_low   ci_high
# 0     0.230646  0.004644 -0.001787  0.011067
# 1     0.206052  0.029238  0.016265  0.041810
# 2     0.230978  0.004312 -0.003223  0.011943
# 3     0.256644 -0.021354 -0.029789 -0.012997
# 4     0.257315 -0.022025 -0.030936 -0.013549
# 5     0.412420  0.003233 -0.004078  0.010820
# 6     0.341231  0.074421  0.057328  0.091263
# 7     0.405543  0.010109  0.001145  0.018777
# 8     0.437152 -0.021500 -0.030438 -0.012403
# 9     0.439545 -0.023893 -0.032635 -0.015282
# 10    0.032565 -0.004248 -0.011266  0.002768
# 11    0.043305 -0.014988 -0.025815 -0.003839
# 12    0.074699 -0.046381 -0.057608 -0.035406
# 13    0.044983 -0.016665 -0.025490 -0.008346
# 14    0.047799 -0.019481 -0.029076 -0.010348
# 15    0.028317 -0.028158 -0.036128 -0.019971
# ### Hypothesis 1 Readout at Top-32
# - Hallucinated vs copied NTM: `0.0046` (95% CI `-0.0018` to `0.0111`)
# - Hallucinated vs copied correct-token DLA: `-0.0042` (95% CI `-0.0113` to `0.0028`)
# - Hallucinated vs 2-token concepts NTM: `0.0292` (95% CI `0.0163` to `0.0418`)
# - Hallucinated vs 2-token concepts correct-token DLA: `-0.0150` (95% CI `-0.0258` to `-0.0038`)
# - Hallucinated vs random NTM: `0.0043` (95% CI `-0.0032` to `0.0119`)
# - Hallucinated vs random correct-token DLA: `-0.0464` (95% CI `-0.0576` to `-0.0354`)
# - Hallucinated vs multiscript NTM: `-0.0214` (95% CI `-0.0298` to `-0.0130`)
# - Hallucinated vs multiscript correct-token DLA: `-0.0167` (95% CI `-0.0255` to `-0.0083`)
# - Hallucinated vs wild NTM: `-0.0220` (95% CI `-0.0309` to `-0.0135`)
# - Hallucinated vs wild correct-token DLA: `-0.0195` (95% CI `-0.0291` to `-0.0103`)
# - Hallucinated wrong-token minus correct-token DLA: `-0.0282` (95% CI `-0.0361` to `-0.0200`)
#
# Within the improbable-bigram set, the traced cache does not show a clear hallucination-specific token-head breakdown. The stronger claim that token-head behavior is similar across all conditions is harder to defend, because the 2-token concept and random-phrase controls are both stronger on the token-head metrics.

# %%
fig, axes, sweep = h1.plot_k_sweep(CACHE, ks=(8, 16, 32, 64, 128))
display(sweep.round(6))
# Out:
#                      metric                condition    k      mean    ci_low  \
# 0           Token NTM (raw)  Hallucinated improbable    8  0.378626  0.368166
# 1           Token NTM (raw)        Copied improbable    8  0.370387  0.362720
# 2           Token NTM (raw)         2-token concepts    8  0.330171  0.314485
# 3           Token NTM (raw)           Random phrases    8  0.271408  0.263349
# 4           Token NTM (raw)      Multiscript bigrams    8  0.321909  0.309752
# ..                      ...                      ...  ...       ...       ...
# 65  Concept wrong-token DLA  Hallucinated improbable    8  0.024541  0.010956
# 66  Concept wrong-token DLA  Hallucinated improbable   16  0.011550  0.004981
# 67  Concept wrong-token DLA  Hallucinated improbable   32  0.004464  0.001129
# 68  Concept wrong-token DLA  Hallucinated improbable   64  0.002851  0.000170
# 69  Concept wrong-token DLA  Hallucinated improbable  128  0.001501 -0.000017
#
#      ci_high
# 0   0.389113
# 1   0.378320
# 2   0.345729
# 3   0.279526
# 4   0.334251
# ..       ...
# 65  0.038155
# 66  0.017980
# 67  0.007630
# 68  0.005439
# 69  0.002964
#
# [70 rows x 6 columns]

# %%
h1.plot_distribution_panels(CACHE, DEFAULT_TOP_K)
# Out:
# (<Figure size 1960x840 with 2 Axes>,
#  array([<Axes: title={'center': 'Top-32 token-head NTM'}, ylabel='Per-example mean'>,
#         <Axes: title={'center': 'Top-32 token-head correct-token DLA'}, ylabel='Per-example mean'>],
#        dtype=object))

# %%
h1.plot_hallucinated_dla_pair(CACHE, DEFAULT_TOP_K)
# Out:
# (<Figure size 1540x630 with 2 Axes>,
#  array([<Axes: title={'center': 'Hallucinated examples only, top-32 token heads'}, xlabel='Correct-token DLA', ylabel='Predicted wrong-token DLA'>,
#         <Axes: title={'center': 'Positive values favor the correct token'}, xlabel='Correct-token DLA minus wrong-token DLA', ylabel='Number of hallucinated examples'>],
#        dtype=object))

# %%
h1.plot_top_head_heatmap(CACHE, top_k=16)
# Out:
# (<Figure size 2170x784 with 4 Axes>,
#  array([<Axes: title={'center': 'Top-16 token heads: NTM'}>,
#         <Axes: title={'center': 'Top-16 token heads: DLA'}>], dtype=object))

# %% [markdown]
# ## Are The Highest-DLA Heads Token-Copying Or Concept-Copying?
#
# This section ranks heads by mean DLA and checks whether those heads also appear in the identified token-copying or concept-copying rankings.

# %%
TOP_DLA_N = 20
COMPARE_K = 32
SOURCES = [
    "hallucinated_correct",
    "hallucinated_wrong",
    "copied_correct",
    "concepts_correct",
    "random_correct",
]

membership_summary = h1.summarize_top_dla_membership(
    CACHE,
    sources=SOURCES,
    top_n=TOP_DLA_N,
    compare_k=COMPARE_K,
)
display(membership_summary)

for source in SOURCES:
    table = h1.top_dla_membership_table(
        CACHE,
        source=source,
        top_n=TOP_DLA_N,
        compare_k=COMPARE_K,
    )
    display(Markdown(f"### {table['source'].iloc[0]}"))
    display(
        table[
            [
                "head",
                "mean_dla",
                "membership_label",
                "in_token_top_k",
                "in_concept_top_k",
                "token_rank",
                "concept_rank",
            ]
        ].round({"mean_dla": 6})
    )
# Out:
#                                 source  top_n  compare_k  token_overlap  \
# 0       Hallucinated correct-token DLA     20         32              3
# 1         Hallucinated wrong-token DLA     20         32              3
# 2  Copied-improbable correct-token DLA     20         32              3
# 3    2-token-concept correct-token DLA     20         32              4
# 4      Random-phrase correct-token DLA     20         32              4
#
#    concept_overlap  both_overlap  neither_overlap  mean_token_rank  \
# 0                2             0               15           304.05
# 1                2             0               15           377.10
# 2                2             0               15           351.45
# 3                1             0               15           316.05
# 4                0             0               16           311.95
#
#    mean_concept_rank
# 0             329.85
# 1             309.75
# 2             265.85
# 3             375.55
# 4             422.60
# ### Hallucinated correct-token DLA
#      head  mean_dla membership_label  in_token_top_k  in_concept_top_k  \
# 0    31.1  0.679926       Token only            True             False
# 1    27.6  0.504683          Neither           False             False
# 2    26.3  0.393189          Neither           False             False
# 3   26.13  0.368828          Neither           False             False
# 4    22.1  0.341393          Neither           False             False
# 5    20.1  0.289925     Concept only           False              True
# 6   24.18  0.247699          Neither           False             False
# 7   31.21  0.216208          Neither           False             False
# 8    29.9  0.210028          Neither           False             False
# 9   28.22  0.207026          Neither           False             False
# 10  31.20  0.192690          Neither           False             False
# 11  30.12  0.172901          Neither           False             False
# 12  28.23  0.171189          Neither           False             False
# 13  29.26  0.142962          Neither           False             False
# 14   21.2  0.126381          Neither           False             False
# 15  16.20  0.116124       Token only            True             False
# 16  22.29  0.105619          Neither           False             False
# 17  30.24  0.101001       Token only            True             False
# 18  27.20  0.097234     Concept only           False              True
# 19   18.4  0.097134          Neither           False             False
#
#     token_rank  concept_rank
# 0           32           300
# 1          675           164
# 2           35           667
# 3          376            42
# 4          401           154
# 5          406             5
# 6          150           624
# 7          383           299
# 8          419           503
# 9          373           175
# 10         371           297
# 11         553           378
# 12         295           123
# 13         987           128
# 14          38            90
# 15          11          1023
# 16         108           553
# 17          13           336
# 18         397             4
# 19          58           732
# ### Hallucinated wrong-token DLA
#      head  mean_dla membership_label  in_token_top_k  in_concept_top_k  \
# 0    31.1  0.406056       Token only            True             False
# 1   24.22  0.354316          Neither           False             False
# 2    29.9  0.263772          Neither           False             False
# 3    31.5  0.231792          Neither           False             False
# 4    28.0  0.210434          Neither           False             False
# 5   30.26  0.206211          Neither           False             False
# 6    27.6  0.202368          Neither           False             False
# 7    26.3  0.195278          Neither           False             False
# 8    25.7  0.180072          Neither           False             False
# 9   31.21  0.174367          Neither           False             False
# 10   25.6  0.154083          Neither           False             False
# 11  26.13  0.149893          Neither           False             False
# 12   27.7  0.134304       Token only            True             False
# 13   20.1  0.099402     Concept only           False              True
# 14  27.20  0.098326     Concept only           False              True
# 15  31.20  0.097859          Neither           False             False
# 16  15.30  0.089506       Token only            True             False
# 17  28.22  0.082076          Neither           False             False
# 18   22.1  0.074917          Neither           False             False
# 19  31.25  0.066904          Neither           False             False
#
#     token_rank  concept_rank
# 0           32           300
# 1          156           223
# 2          419           503
# 3         1003           289
# 4          454           558
# 5          103           482
# 6          675           164
# 7           35           667
# 8          836           250
# 9          383           299
# 10          83           383
# 11         376            42
# 12          14           186
# 13         406             5
# 14         397             4
# 15         371           297
# 16           1           906
# 17         373           175
# 18         401           154
# 19        1024           308
# ### Copied-improbable correct-token DLA
#      head  mean_dla membership_label  in_token_top_k  in_concept_top_k  \
# 0    31.1  0.656644       Token only            True             False
# 1    27.6  0.494277          Neither           False             False
# 2    26.3  0.367138          Neither           False             False
# 3   26.13  0.361630          Neither           False             False
# 4    29.9  0.256109          Neither           False             False
# 5    20.1  0.237222     Concept only           False              True
# 6   27.20  0.232224     Concept only           False              True
# 7   30.12  0.228424          Neither           False             False
# 8   31.20  0.210721          Neither           False             False
# 9   31.21  0.182055          Neither           False             False
# 10   22.1  0.147212          Neither           False             False
# 11  29.26  0.142387          Neither           False             False
# 12  28.22  0.133759          Neither           False             False
# 13   27.7  0.127274       Token only            True             False
# 14  22.29  0.114422          Neither           False             False
# 15  28.23  0.113276          Neither           False             False
# 16  24.18  0.113027          Neither           False             False
# 17  30.24  0.112291       Token only            True             False
# 18   21.2  0.111062          Neither           False             False
# 19   31.5  0.108229          Neither           False             False
#
#     token_rank  concept_rank
# 0           32           300
# 1          675           164
# 2           35           667
# 3          376            42
# 4          419           503
# 5          406             5
# 6          397             4
# 7          553           378
# 8          371           297
# 9          383           299
# 10         401           154
# 11         987           128
# 12         373           175
# 13          14           186
# 14         108           553
# 15         295           123
# 16         150           624
# 17          13           336
# 18          38            90
# 19        1003           289
# ### 2-token-concept correct-token DLA
#      head  mean_dla membership_label  in_token_top_k  in_concept_top_k  \
# 0   30.26  0.965455          Neither           False             False
# 1    29.9  0.805157          Neither           False             False
# 2    31.1  0.771567       Token only            True             False
# 3   27.20  0.579662     Concept only           False              True
# 4   29.11  0.529308          Neither           False             False
# 5   28.18  0.354873          Neither           False             False
# 6    31.7  0.315301          Neither           False             False
# 7   29.21  0.309358       Token only            True             False
# 8    31.6  0.282855          Neither           False             False
# 9    26.3  0.250868          Neither           False             False
# 10   30.2  0.245654          Neither           False             False
# 11  31.10  0.214612          Neither           False             False
# 12   27.6  0.210674          Neither           False             False
# 13  29.24  0.206338          Neither           False             False
# 14   18.4  0.192341          Neither           False             False
# 15  30.30  0.192100          Neither           False             False
# 16   27.7  0.190042       Token only            True             False
# 17  30.24  0.184320       Token only            True             False
# 18  30.15  0.162025          Neither           False             False
# 19   28.0  0.144983          Neither           False             False
#
#     token_rank  concept_rank
# 0          103           482
# 1          419           503
# 2           32           300
# 3          397             4
# 4          609           409
# 5          224           134
# 6          792           296
# 7            7           530
# 8          414           317
# 9           35           667
# 10         657           509
# 11         928           309
# 12         675           164
# 13         171           280
# 14          58           732
# 15          74           585
# 16          14           186
# 17          13           336
# 18         245           210
# 19         454           558
# ### Random-phrase correct-token DLA
#      head  mean_dla membership_label  in_token_top_k  in_concept_top_k  \
# 0    31.0  0.800690       Token only            True             False
# 1    27.4  0.560096          Neither           False             False
# 2   30.12  0.419184          Neither           False             False
# 3   30.24  0.390808       Token only            True             False
# 4   28.20  0.367098          Neither           False             False
# 5   25.13  0.342448          Neither           False             False
# 6   25.14  0.339357          Neither           False             False
# 7   24.18  0.335053          Neither           False             False
# 8   30.30  0.334573          Neither           False             False
# 9   24.16  0.322207          Neither           False             False
# 10   27.6  0.316920          Neither           False             False
# 11  25.15  0.310799          Neither           False             False
# 12  28.23  0.270559          Neither           False             False
# 13   27.7  0.267549       Token only            True             False
# 14  31.14  0.252435       Token only            True             False
# 15  22.28  0.240354          Neither           False             False
# 16  24.17  0.240090          Neither           False             False
# 17   28.0  0.236082          Neither           False             False
# 18   23.5  0.226086          Neither           False             False
# 19  29.31  0.224801          Neither           False             False
#
#     token_rank  concept_rank
# 0           20           318
# 1          144           346
# 2          553           378
# 3           13           336
# 4          140           103
# 5          244           516
# 6           99           643
# 7          150           624
# 8           74           585
# 9          597           398
# 10         675           164
# 11         216           660
# 12         295           123
# 13          14           186
# 14           6           301
# 15         907           923
# 16         571           455
# 17         454           558
# 18         310            91
# 19         757           744

# %%
SAVE_DIR = ROOT / "scripts" / "hypothesis1_figures"
SAVE_DIR.mkdir(parents=True, exist_ok=True)

_ = h1.plot_k_sweep(
    CACHE, ks=(8, 16, 32, 64, 128), save_path=SAVE_DIR / "hypothesis1_k_sweep.png"
)
_ = h1.plot_distribution_panels(
    CACHE, DEFAULT_TOP_K, save_path=SAVE_DIR / "hypothesis1_distributions.png"
)
_ = h1.plot_hallucinated_dla_pair(
    CACHE, DEFAULT_TOP_K, save_path=SAVE_DIR / "hypothesis1_hallucinated_dla_pair.png"
)
_ = h1.plot_top_head_heatmap(
    CACHE, top_k=16, save_path=SAVE_DIR / "hypothesis1_top_token_heads.png"
)
SAVE_DIR
# Out:
# PosixPath('/Users/eugenejang/Workspace/improbable-bigram-causality/dual-route-induction/scripts/hypothesis1_figures')

# %% [markdown]
# ---
#
# # Concept-Copying Head Analysis
#
# The cells below come from `concept_copying_analysis.ipynb` and reuse the same loaded cache and helper module from the setup cell above.

# %% [markdown]
# ## Coverage
#
# The proposal's concept-head diagnostic compares three conditions:
#
# 1. hallucinated improbable bigrams
# 2. random two-token phrases
# 3. coherent two-token concepts
#
# All three conditions are now present in the current cache, with copied improbable examples still serving as an additional internal control. The notebook can therefore compare hallucinated prompts directly against both coherent 2-token concepts and random two-token phrases.

# %%
summary = h1.build_concept_pairwise_summary(CACHE, DEFAULT_TOP_K)
display(summary.round(6))
display(Markdown(h1.concept_interpretation_markdown(CACHE, DEFAULT_TOP_K)))
# Out:
#                           metric                       comparison  left_mean  \
# 0              Concept LTM (raw)            Hallucinated - Copied   0.116455
# 1              Concept LTM (raw)  Hallucinated - 2-token concepts   0.116455
# 2              Concept LTM (raw)            Hallucinated - Random   0.116455
# 3              Concept LTM (raw)       Hallucinated - Multiscript   0.116455
# 4              Concept LTM (raw)              Hallucinated - Wild   0.116455
# 5   Concept LTM (value-weighted)            Hallucinated - Copied   0.208502
# 6   Concept LTM (value-weighted)  Hallucinated - 2-token concepts   0.208502
# 7   Concept LTM (value-weighted)            Hallucinated - Random   0.208502
# 8   Concept LTM (value-weighted)       Hallucinated - Multiscript   0.208502
# 9   Concept LTM (value-weighted)              Hallucinated - Wild   0.208502
# 10     Concept correct-token DLA            Hallucinated - Copied   0.012878
# 11     Concept correct-token DLA  Hallucinated - 2-token concepts   0.012878
# 12     Concept correct-token DLA            Hallucinated - Random   0.012878
# 13     Concept correct-token DLA       Hallucinated - Multiscript   0.012878
# 14     Concept correct-token DLA              Hallucinated - Wild   0.012878
# 15      Hallucinated concept DLA      Wrong-token - Correct-token   0.004464
#
#     right_mean      diff    ci_low   ci_high
# 0     0.114890  0.001565 -0.003325  0.006413
# 1     0.156531 -0.040076 -0.045979 -0.034597
# 2     0.093577  0.022878  0.016370  0.029347
# 3     0.085046  0.031410  0.026288  0.036231
# 4     0.082911  0.033544  0.028010  0.038778
# 5     0.204192  0.004310 -0.004211  0.013113
# 6     0.284429 -0.075927 -0.086592 -0.065399
# 7     0.171096  0.037405  0.027426  0.047668
# 8     0.156871  0.051631  0.043240  0.059998
# 9     0.149248  0.059254  0.050033  0.068270
# 10    0.014698 -0.001821 -0.004804  0.001088
# 11    0.028616 -0.015738 -0.026071 -0.006969
# 12    0.009735  0.003143 -0.000756  0.006694
# 13    0.018776 -0.005898 -0.010294 -0.001819
# 14    0.016487 -0.003609 -0.008397  0.000858
# 15    0.012878 -0.008414 -0.012045 -0.004922
# ### Concept-Head Readout at Top-32
# - Hallucinated vs copied LTM: `0.0016` (95% CI `-0.0033` to `0.0064`)
# - Hallucinated vs copied correct-token DLA: `-0.0018` (95% CI `-0.0048` to `0.0011`)
# - Hallucinated vs 2-token concepts LTM: `-0.0401` (95% CI `-0.0460` to `-0.0346`)
# - Hallucinated vs 2-token concepts correct-token DLA: `-0.0157` (95% CI `-0.0261` to `-0.0070`)
# - Hallucinated vs random LTM: `0.0229` (95% CI `0.0164` to `0.0293`)
# - Hallucinated vs random correct-token DLA: `0.0031` (95% CI `-0.0008` to `0.0067`)
# - Hallucinated vs multiscript LTM: `0.0314` (95% CI `0.0263` to `0.0362`)
# - Hallucinated vs multiscript correct-token DLA: `-0.0059` (95% CI `-0.0103` to `-0.0018`)
# - Hallucinated vs wild LTM: `0.0335` (95% CI `0.0280` to `0.0388`)
# - Hallucinated vs wild correct-token DLA: `-0.0036` (95% CI `-0.0084` to `0.0009`)
# - Hallucinated wrong-token minus correct-token DLA: `-0.0084` (95% CI `-0.0120` to `-0.0049`)
#
# The current cache includes hallucinated improbable bigrams, copied improbable prompts, coherent 2-token concepts, and random two-token phrases. That allows a direct check of whether concept-head behavior on hallucinated prompts looks more like the coherent concept condition or like the random-token control. In the current traced cache, concept heads do not cleanly separate hallucinated prompts from both copied improbable prompts and coherent 2-token concepts, and they do not strongly favor the wrong token over the correct token in hallucinated cases.

# %%
fig, axes, sweep = h1.plot_concept_k_sweep(CACHE, ks=(8, 16, 32, 64, 128))
display(sweep.round(6))
# Out:
#                    metric                condition    k      mean    ci_low  \
# 0       Concept LTM (raw)  Hallucinated improbable    8  0.226588  0.214730
# 1       Concept LTM (raw)        Copied improbable    8  0.223119  0.217660
# 2       Concept LTM (raw)         2-token concepts    8  0.357382  0.348788
# 3       Concept LTM (raw)           Random phrases    8  0.157330  0.145627
# 4       Concept LTM (raw)      Multiscript bigrams    8  0.122995  0.116796
# ..                    ...                      ...  ...       ...       ...
# 65  Token wrong-token DLA  Hallucinated improbable    8 -0.065256 -0.082846
# 66  Token wrong-token DLA  Hallucinated improbable   16 -0.020745 -0.028902
# 67  Token wrong-token DLA  Hallucinated improbable   32  0.000159 -0.005114
# 68  Token wrong-token DLA  Hallucinated improbable   64  0.002308 -0.000797
# 69  Token wrong-token DLA  Hallucinated improbable  128  0.002936  0.000049
#
#      ci_high
# 0   0.236404
# 1   0.228499
# 2   0.366046
# 3   0.169329
# 4   0.129637
# ..       ...
# 65 -0.047740
# 66 -0.012161
# 67  0.006495
# 68  0.005938
# 69  0.006018
#
# [70 rows x 6 columns]

# %%
h1.plot_concept_distribution_panels(CACHE, DEFAULT_TOP_K)
# Out:
# (<Figure size 1960x840 with 2 Axes>,
#  array([<Axes: title={'center': 'Top-32 concept-head LTM'}, ylabel='Per-example mean'>,
#         <Axes: title={'center': 'Top-32 concept-head correct-token DLA'}, ylabel='Per-example mean'>],
#        dtype=object))

# %%
h1.plot_concept_hallucinated_dla_pair(CACHE, DEFAULT_TOP_K)
# Out:
# (<Figure size 1540x630 with 2 Axes>,
#  array([<Axes: title={'center': 'Hallucinated examples only, top-32 concept heads'}, xlabel='Correct-token DLA', ylabel='Predicted wrong-token DLA'>,
#         <Axes: title={'center': 'Positive values favor the correct token'}, xlabel='Correct-token DLA minus wrong-token DLA', ylabel='Number of hallucinated examples'>],
#        dtype=object))

# %%
h1.plot_concept_head_heatmap(CACHE, top_k=16)
# Out:
# (<Figure size 2170x784 with 4 Axes>,
#  array([<Axes: title={'center': 'Top-16 concept heads: LTM'}>,
#         <Axes: title={'center': 'Top-16 concept heads: DLA'}>],
#        dtype=object))

# %%
SAVE_DIR = ROOT / "scripts" / "concept_head_figures"
SAVE_DIR.mkdir(parents=True, exist_ok=True)

_ = h1.plot_concept_k_sweep(
    CACHE, ks=(8, 16, 32, 64, 128), save_path=SAVE_DIR / "concept_k_sweep.png"
)
_ = h1.plot_concept_distribution_panels(
    CACHE, DEFAULT_TOP_K, save_path=SAVE_DIR / "concept_distributions.png"
)
_ = h1.plot_concept_hallucinated_dla_pair(
    CACHE, DEFAULT_TOP_K, save_path=SAVE_DIR / "concept_hallucinated_dla_pair.png"
)
_ = h1.plot_concept_head_heatmap(
    CACHE, top_k=16, save_path=SAVE_DIR / "concept_top_heads.png"
)
SAVE_DIR
# Out:
# PosixPath('/Users/eugenejang/Workspace/improbable-bigram-causality/dual-route-induction/scripts/concept_head_figures')
